# %%
for row in csvreader:
        print(prev_month)
      #  print(line_num)
        
        monthly_profit = int(row[1])
        print(monthly_profit)
        revenue_change = monthly_profit - prev_month
        print(revenue_change)
        change_count += 1
        prev_month = monthly_profit
        print(change_count)
percent_av = (revenue_change/change_count)
#line_num += 1   #? 

#line_num = 0   #?



        if minimum_value == 0:
            minimum_value = market_cap     # Logic to determine min value and associated key
            minimum_key = row[0] #date
        elif market_cap < minimum_value:
            minimum_value = market_cap
            minimum_key = row[0] #date
        if market_cap > maximum_value:    # Logic to determine max value and associated key
            maximum_value = market_cap
            maximum_key = row[0] #date
        # print(type(monthly_profit)) #int
       # print(type(prev_month))  #string
      #  changed_value.append(revenue_change)
       # row[2]=(revenue_change)
       # date_growth_file.update({row[0]:row[2]})
      # Logic to determine min value and associated key
#if minimum_value == 0:
#        minimum_value = market_cap
 #       minimum_key = bank_name
#elif market_cap < minimum_value:
 #       minimum_value = market_cap
  #      minimum_key = bank_name

    # Logic to determine max value and associated key
#if market_cap > maximum_value:
 #       maximum_value = market_cap
  #      maximum_key = bank_name

       # def percent_change(old, new):
        #   pc = round((new - old) / abs(old) * 100, 2)
         #  print(f"from {old} to {new}   -> {pc}% change")
          # changed_value.append(int(changed_value[i]) - changed_value[i-1])
    #print(changed_value)
            # for value in index.data[1:-1]
            # Calculating difference list
 ###############
data = {}
aa = "date"
#monthly_interval = [] # could use this to create a library
#date_growth_file = {}
#range_end = int(len(revenue) - 1) 
## data.update({row[0]:row[1]})

#revenue = [] # ? 
#changed_value = [] # average change
#with open(pyb, 'w') as csvfile:
    # Set the file object as a csvwriter object
   # csvwriter = csv.writer(csvfile, delimiter=',')
    # Write the header to the output file
    #csvwriter.writerow(header)
    # Write the list of metrics to the output file
    #csvwriter.writerow(metrics)



 #  print (row)
#  print(type(csvfile))  # not sure if I want or need this
                            #  writer = csv.writer
  #  print(type(csvreader))   # not sure if I want or need this
#  print(f"{header} <---- HEADER")  # this header is yet to be decided on
#alt_total_months = len(revenue)    #also works in this example
 # this line may need a line_num +=1 counter inserted above 
# revenue.append(profit_loss)
# print(data)
#print(total_revenue)

#print(total_months) # correct

#print(total_revenue)
#print(alt_total_months) # correct      
#checker = {} 
       # print (row)
       ## print(averages_count)
      ##  print("________")
      ##  print(prev_month)
### print(revenue_change)
###   print(row[0], int(row[1]))  

# printing difference list
# print ("difference list: ", str(diff_list))
            
 # idea is right: & code correct answer is appropriate here -unsure if it works in all situation

 # for interval in months('Date') subtract p/l from date +1 p/L & calculate % change of this
    
    # "C:\Users\garry\Desktop\pets\cats\name.txt"
# 'C:\Users\garry\Desktop\Instructions\PyBank\Resources\budget_data.csv'
# delimiter=
# datadict = dict(csvreader) not working
# date = row[0]
# date = row[0]
#  if min_var == 0:
     #   min_var = object
   #  elif object > max_var:
     #   max_var = object
   #  elif object < min_var:
     #   min_var = object
# for difference in data
#print(change_count)

#sol_max = ["Greatest ","Increase ", "in ","Profits: "] 
#sol_min = ["Greatest ","Decrease ","in ","Profits: "]
print(round(percent_av,2))
#print(maximum_key, maximum_value)
#print(minimum_key, minimum_value)
#Financial Analysis
 # ----------------------------
 # Total Months: 86
 # Total: $38382578
 # Average  Change: $-2315.12
 # Greatest Increase in Profits: Feb-2012 ($1926159)
 # Greatest Decrease in Profits: Sep-2013 ($-2196167#)

#  Average  Change: $-2315.12
 # Greatest Increase in Profits: Feb-2012 ($1926159)
  #Greatest Decrease in Profits: Sep-2013 ($-2196167)
